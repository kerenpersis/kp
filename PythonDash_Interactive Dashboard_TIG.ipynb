# %% [markdown]
# <a href="https://colab.research.google.com/github/kerenpersis/kp/blob/main/PythonDash_Interactive%20Dashboard_TIG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install dash
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 44.3 MB/s eta 0:00:00
# ...

# %%
# !pip install plotly-express

# %%
import plotly.express as px

# %%
import dash
from dash import html, dcc
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-59ac9666-44fb-4332-b905-f2e36c5fb87c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59ac9666-44fb-4332-b905-f2e36c5fb87c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import json
import pandas as pd


data = uploaded

# %%
scalar_values = [value for value in data.values() if not isinstance(value, dict)]
if scalar_values:
    print("Data contains scalar values.")
# Create a list of dictionaries from the scalar values
dict_list = [{"value": value} for value in scalar_values]

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(dict_list)
# Out:
# Data contains scalar values.

# %%
df = pd.read_json('jsondata (1).json')

# %%
app = dash.Dash(__name__)

# %%
print(df.columns)
# Out:
# Index(['end_year', 'intensity', 'sector', 'topic', 'insight', 'url', 'region',
#        'start_year', 'impact', 'added', 'published', 'country', 'relevance',
#        'pestle', 'source', 'title', 'likelihood'],
#       dtype='object')

# %%
print(df.empty)
# Out:
# False

# %%
# Investigate the data types of the columns
print(df['sector'].dtype)
print(df['topic'].dtype)
# Out:
# object
# object

# %%
df.head()
# Out:
#   end_year intensity       sector        topic  \
# 0                  6       Energy          gas
# 1                  6       Energy          oil
# 2                  6       Energy  consumption
# 3                  6  Environment          oil
# 4                  6                    market
#
#                                              insight  \
# 0                              Annual Energy Outlook
# 1                              Annual Energy Outlook
# 2                              Annual Energy Outlook
# 3  WRI Partnership Aims to Foster Supply Chain Tr...
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...
#
#                                                  url            region  \
# 0  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 1  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 2  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# ...

# %%
app.layout = html.Div([
    html.H1("Dashboard"),

    dcc.Graph(
        id='sector-distribution',
        figure=px.bar(df['sector'].value_counts(), title='Sector Distribution')
    ),

    dcc.Graph(
        id='topic-distribution',
        figure=px.bar(df['topic'].value_counts(), title='Topic Distribution')
    ),
])

# %%
import dash
from dash import html, dcc, callback_context
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Assuming you've already loaded your data into a DataFrame called 'df'

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("Interactive Dashboard"),

    # Dropdown for selecting sector
    dcc.Dropdown(
        id='sector-dropdown',
        options=[{'label': sector, 'value': sector} for sector in df['sector'].unique()],
        value='Energy',  # Default value
        multi=True,  # Allow multiple selections
        placeholder="Select sector(s)"
    ),

    # Bar plot for sector distribution
    dcc.Graph(id='sector-distribution'),
])

# Define callback to update sector distribution plot
@app.callback(
    Output('sector-distribution', 'figure'),
    [Input('sector-dropdown', 'value')]
)
def update_sector_distribution(selected_sectors):
    filtered_df = df[df['sector'].isin(selected_sectors)]
    fig = px.bar(filtered_df['sector'].value_counts(), title='Sector Distribution')
    return fig

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
